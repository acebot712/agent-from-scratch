# %% [markdown]
# ## LAB1.5 — the Agent class
# Implements: **LAB1.5 (source V1.5)**
#
# **Learning objective:** run the reusable `Agent` on a multi-step question.
#
# > Needs a key.

# %%
import os, sys
# Import the reference framework (the answer key). You implement pieces in this
# notebook, then check them against this complete version.
sys.path.insert(0, os.path.abspath(os.path.join('..', 'src')))

# %%
from agent import Agent

# %%
# 👉 Your turn (1): construct an Agent with a step-by-step system prompt
# and max_steps=5.
agent = Agent(system_prompt=..., max_steps=...)  # TODO

# %%
# 👉 Your turn (2): run it on a question that needs a few steps.
answer = agent.run(...)  # TODO
print(answer)

# %%
# Inspect the loop's trace:
for m in agent.history:
    print(m['role'], '·', m['content'][:80])

# %% [markdown]
# ### 🔎 Eyeball your output
# The answer should be **40** (km/h). Scroll the history: you should see alternating assistant/user turns ending when the model emits FINAL ANSWER. If `history` is just two messages, it stopped on the first turn — fine if the model one-shotted it.

# %% [markdown]
# ---
# **Stuck on a 👉 Your turn?** The fully-worked version of this lab is `lab_v1_5_answers.ipynb` — peek at one cell, then come back.
