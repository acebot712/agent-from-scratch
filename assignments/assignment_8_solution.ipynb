# %% [markdown]
# # Capstone — build your flagship agent
# Implements: **capstone (Module 8)**
#
# There is no autograder here (the work is open-ended). Instead, build an agent on the framework and self-assess against the rubric. `python grader/grade.py 8` prints the rubric checklist.
#
# ## Rubric
# 1. **Uses the loop** — your agent runs on `Agent`/`ToolAgent` (M1/M2).
# 2. **Tools** — at least one real `Tool` registered and called (M2).
# 3. **Memory** — uses working, episodic, or semantic memory (M3).
# 4. **Planning** — uses ReAct or reflection where it helps (M4).
# 5. **Hardening** — a step/cost cap and at least one guardrail (M7).
# 6. **Evaluated** — you ran it over ≥3 tasks and reported success rate (M6).
#
# Aim for 4/6+. Optional: share for peer review.

# %%
import os, sys
# Prefer your working copy (my_agent/, from `python setup_module.py N`);
# fall back to the reference framework in src/.
for _p in ('../my_agent', '../src'):
    if os.path.isdir(os.path.join(_p, 'agent')):
        sys.path.insert(0, os.path.abspath(_p)); break

# %%
# 👉 Build your capstone here. A starting skeleton:
from agent import Tool, ToolRegistry, ToolAgent

def build():
    reg = ToolRegistry()
    # register your tools ...
    return ToolAgent(reg, max_steps=6, block=['shell'])

# if os.environ.get('RUN_LIVE') == '1':
#     print(build().run('your task here'))

# %% [markdown]
# ### Self-assessment
# Tick the rubric items you hit, and note one thing you'd improve with more time.
